# %% [markdown]
# In this project we go to clan the data and analyze the included used car listings of the eBay Kleinanzeige dataset. This dataset contains informations about cars.

# %%
import pandas as pd
import numpy as np

autos = pd.read_csv("autos.csv", encoding='Latin-1')

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
#renomear todas as colunas colocando no estilo nome_outro
autos.columns=['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'num_pictures', 'postal_code',
       'last_seen']

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-19 17:36:18  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_ps  model  \
# ...

# %%
autos.unrepaired_damage.value_counts()
# Out:
# nein    35232
# ja       4939
# Name: unrepaired_damage, dtype: int64

# %% [markdown]
# columns have one value: nrOfPictures, offerType, seller
# columns that needs more investigation: unrepaired_damage
# text data stored as numeric: postalCode, registration_month
# numeric data stored as text:

# %%
#dropando colunas com valores iguais
autos = autos.drop(columns=['num_pictures', 'offer_type','seller'])

# %%
autos.price = [value.replace('$','').replace(',','') for value in autos.price]
autos.price = pd.to_numeric(autos.price)

# %%
autos.odometer = [value.replace('km','').replace(',','') for value in autos.odometer]
autos.odometer = pd.to_numeric(autos.odometer)

# %%
autos.rename(columns={'odometer':'odometer_km'}, inplace=True)

# %%
autos.odometer_km.unique().shape
# Out:
# (13,)

# %%
autos.odometer_km.describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos.odometer_km.value_counts().sort_index(ascending=True)
# Out:
# 5000        967
# 10000       264
# 20000       784
# 30000       789
# 40000       819
# 50000      1027
# 60000      1164
# 70000      1230
# 80000      1436
# 90000      1757
# 100000     2169
# 125000     5170
# 150000    32424
# Name: odometer_km, dtype: int64

# %%
autos.price.unique().shape
# Out:
# (2357,)

# %%
autos.price.value_counts().sort_index(ascending=False).head(15)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# 350000      1
# 345000      1
# 299000      1
# 295000      1
# 265000      1
# Name: price, dtype: int64

# %% [markdown]
# Considerando os dados acima, percebe-se que os numeros vão aumentando de forma
# proporcional até chegar em 350000, quando logo após ha um salto para 999990 e daí em diante os numeros parecem muito grandes. Por isso, vamos eliminar os valores maiores que 350000.

# %%
autos.price.value_counts().sort_index(ascending=True).head(15)
# Out:
# 0     1421
# 1      156
# 2        3
# 3        1
# 5        2
# 8        1
# 9        1
# 10       7
# 11       2
# 12       3
# 13       2
# 14       1
# 15       2
# 17       3
# 18       1
# Name: price, dtype: int64

# %% [markdown]
# Observando os menores valores há muitos 0, logo não faz sentido para o contexto de um leilão. Vamos eliminá-los

# %%
autos = autos[autos.price.between(1,350000)]

# %%
autos['date_crawled'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
autos.registration_year.value_counts(normalize=True)
# Out:
# 2000    0.064985
# 2005    0.060455
# 1999    0.059652
# 2004    0.055657
# 2003    0.055575
#           ...
# 9000    0.000021
# 1948    0.000021
# 1000    0.000021
# 1931    0.000021
# 1952    0.000021
# Name: registration_year, Length: 95, dtype: float64

# %%
autos.brand.unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'seat', 'renault', 'mercedes_benz', 'audi', 'sonstige_autos',
#        'opel', 'mazda', 'porsche', 'mini', 'toyota', 'dacia', 'nissan',
#        'jeep', 'saab', 'volvo', 'mitsubishi', 'jaguar', 'fiat', 'skoda',
#        'subaru', 'kia', 'citroen', 'chevrolet', 'hyundai', 'honda',
#        'daewoo', 'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'lada',
#        'rover', 'daihatsu', 'lancia'], dtype=object)

# %%
first_20_brands = autos.brand.value_counts().head(20).index

# %% [markdown]
# foi escolhido agregar pelas 20 primeiras marcas que mais aparecem no conjunto de dados

# %%
dict_agg_brand={}
dict_agg_km={}
for brand in first_20_brands:
    mean_price_brand = autos[autos['brand']==brand]['price'].mean()
    mean_km_brand = autos[autos['brand']==brand]['odometer_km'].mean()
    dict_agg_brand[brand]=mean_price_brand 
    dict_agg_km[brand]=mean_km_brand

# %%
brand_mean_series = pd.Series(dict_agg_brand)
km_mean_series = pd.Series(dict_agg_km)

# %%
df_brand_mean = pd.DataFrame(brand_mean_series, columns=['mean_price'])

# %%
df_brand_mean['mean_km'] = km_mean_series

# %%
df_brand_mean.sort_index()
# Out:
#                   mean_price        mean_km
# audi             9212.930662  129492.562380
# bmw              8261.382442  132682.973075
# citroen          3761.895044  119992.711370
# fiat             2793.870048  117567.353407
# ford             3728.412182  124349.497339
# hyundai          5371.792961  106718.426501
# mazda            4059.059540  124871.447903
# mercedes_benz    8536.027085  130796.431642
# mini            10541.566986   88899.521531
# nissan           4669.385965  118711.201080
# opel             2944.607542  129383.172257
# peugeot          3065.611888  127356.643357
# renault          2431.195699  128062.365591
# seat             4315.744565  121641.304348
# skoda            6353.544872  110993.589744
# smart            3518.102305  100511.527378
# sonstige_autos  12149.169851   90180.467091
# toyota           5148.003273  116219.312602
# volkswagen       5332.478425  128896.575077
# volvo            4866.993166  138337.129841

# %% [markdown]
# Observando o dataframe, a media de quilometragem não tem relação com a média de preços
